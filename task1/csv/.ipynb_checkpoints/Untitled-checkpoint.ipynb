# %%
import pandas as pd

# %%
df = pd.read_csv("./non_random_mcts.csv")
df.head(20)
# Out:
#      n  popularity  avg. convincity  avg. playouts  avg. path  med. path   \
# 0    3         115           1.0000      6794.8870     2.0000           2
# 1    4         185           0.0144      5225.7351     2.6667           3
# 2    6          17           0.9907      4203.7647     3.5705           4
# 3    7          98           0.9904      4155.6122     3.7786           4
# 4    8         185           0.0573      3335.9081     4.5074           5
# 5    9           6           0.9350      2829.5000     5.1534           5
# 6   10          29           0.9236      2635.5862     5.2822           5
# 7   11          80           0.9276      2631.5625     5.3973           5
# 8   12         185           0.2374      2128.6703     5.9648           6
# 9   13         111           0.6772      1547.5045     6.6294           7
# 10  14          80           0.6941      1446.9000     6.5735           7
# 11  15          94           0.7291      1373.1170     6.5668           7
# ...

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(8, 3))

xlabel = "n"
ylabel = "avg. playouts"
title = "Non-random MCTS"

x = df[xlabel]
y = df[ylabel]

plt.bar(x,y,align='center')

plt.xlabel(xlabel)
plt.ylabel(ylabel)
plt.title(title)
plt.show()

# %%
import seaborn as sns
N = 10
x = list(range(1,N+1))

p_10 = list(pd.read_csv("10_ms.csv")["avg. playouts"])
p_30 = list(pd.read_csv("30_ms.csv")["avg. playouts"])
p_100 = list(pd.read_csv("100_ms.csv")["avg. playouts"])

df = pd.DataFrame(zip(x*N, ["10"]*N+["30"]*N+["100"]*N, p_10+p_30+p_100), columns=["n", "time", "avg. plyouts"])
plt.figure(figsize=(10, 6))
sns.barplot(x="n", hue="time", y="avg. plyouts", data=df)
plt.show()
